# %% [markdown]
# ## Linear Algebra Exercise Pack (Core + Python)

# %% [markdown]
# Designed for your Maths–DS–ML Sprint (15 days, 5h/day) David, this pack is meant to be used daily — each block is self‑contained and builds toward DS/ML fluency.

# %% [markdown]
# ### 📘 Block 3 — Subspaces

# %% [markdown]
# #### Visuals
#
# 9. (https://ts3.mm.bing.net/th?id=OIP.7QA6pXszvIdF5_TH7ZLU6gHaFj&pid=15.1&o=7&rm=3)
# 10. (https://ts4.mm.bing.net/th?id=OIP.g9rTCQEOoOqZW8RghN79YgHaEk&pid=15.1&o=7&rm=3)
# 11. (https://ts3.mm.bing.net/th?id=OIP.tTks6eo-VMeOxHOeARE-iQHaEM&pid=15.1&o=7&rm=3)
# 12. (https://ts3.mm.bing.net/th?id=OIP.X5QJivisDlb5j3XgRMfTjgHaEK&pid=15.1&o=7&rm=3)

# %% [markdown]
# #### Definitions

# %% [markdown]
# #### Exercises
#
# Closure under addition — Verify if a set is closed under addition.
#
# Closure under scalar multiplication — Test closure under scalars.
#
# Polynomial subspaces — Determine if sets of polynomials form subspaces.

# %% [markdown]
# #### Python tasks

# %%
import numpy as np

A = np.array([
    [1, 2, 3],
    [2, 4, 6],
    [1, 0, 1]
])
#TODO

#rank = np.linalg.matrix_rank(A)
#print("Rank:", rank)
#print("Independent?" if rank == A.shape[1] else "Dependent")

def is_closed_addition(S):
    for a in S:
        for b in S:
            if not any(np.allclose(a+b, c) for c in S):
                return False
    return True
