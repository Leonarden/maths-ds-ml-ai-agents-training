# %% [markdown]
# ## Linear Algebra Exercise Pack (Core + Python)

# %% [markdown]
# Designed for your Maths–DS–ML Sprint (15 days, 5h/day) David, this pack is meant to be used daily — each block is self‑contained and builds toward DS/ML fluency.

# %% [markdown]
# ### 📘 Block 4 — Basis & Dimension

# %% [markdown]
# #### Visuals
# 13. (https://ts2.mm.bing.net/th?id=OIP.GArnGslzlIO0eDEQrRJerwHaEK&pid=15.1&o=7&rm=3)
# 14. (https://ts4.mm.bing.net/th?id=OIP.cWt4cUa0wG5YPmBHSiU6owHaFj&pid=15.1&o=7&rm=3)
# 15. (https://ts1.mm.bing.net/th?id=OIP.SzWfyySNRm4aqiF31RHrzQHaG7&pid=15.1&o=7&rm=3)
# 16. (https://ts1.mm.bing.net/th?id=OIP.Qe4VdLGzh3HLbk66WcutWAHaF6&pid=15.1&o=7&rm=3)

# %% [markdown]
# #### Definitions

# %% [markdown]
# #### Exercises
#
# Find a basis — Extract a basis from a set of vectors.
#
# Dimension proof — Show that all bases of a finite-dimensional space have the same number of elements.
#
# Coordinate representation — Express vectors in terms of a given basis.

# %% [markdown]
# #### Python tasks

# %%
import numpy as np

A = np.array([[1,2],[3,4],[5,6]])
Q, R = np.linalg.qr(A)

basis = Q[:, :np.linalg.matrix_rank(A)]

print("Basis:\n", basis)
# Out:
# Basis:
#  [[-0.16903085  0.89708523]
#  [-0.50709255  0.27602622]
#  [-0.84515425 -0.34503278]]
