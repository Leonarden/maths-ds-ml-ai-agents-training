# %% [markdown]
# ## Linear Algebra Exercise Pack (Core + Python)

# %% [markdown]
# Designed for your Maths–DS–ML Sprint (15 days, 5h/day) David, this pack is meant to be used daily — each block is self‑contained and builds toward DS/ML fluency.

# %% [markdown]
# ### 📘 Block 8 — ML‑Relevant Linear Algebra

# %% [markdown]
# #### Visuals
#
# 29. (https://ts2.mm.bing.net/th?id=OIP.uw-Dwl1sZvN4_wVMCuS-ggHaEK&pid=15.1&o=7&rm=3)
# 30. (https://ts1.mm.bing.net/th?id=OIP.-ehwEG2baWO6kqktKGHp3QHaDt&pid=15.1&o=7&rm=3)
# 31. (https://ts4.mm.bing.net/th?id=OIP.EaMUlvdoBavRMi__UsftnQHaFS&pid=15.1&o=7&rm=3)
# 32. (https://ts1.mm.bing.net/th?id=OIP.UHqLLJBcH1Y5IANK-XbFDwHaE0&pid=15.1&o=7&rm=3)

# %% [markdown]
# #### Definitions

# %% [markdown]
# #### Exercises
#
# Least squares
#
# Gradient intuition
#
# Matrix norms

# %% [markdown]
# #### Python tasks

# %%
import numpy as np

X = np.array([[1,1],[1,2],[1,3]])
y = np.array([1,2,2])

theta = np.linalg.inv(X.T @ X) @ X.T @ y
print("Least squares solution:", theta)
# Out:
# Least squares solution: [0.66666667 0.5       ]
