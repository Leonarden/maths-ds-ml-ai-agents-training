# %% [markdown]
# ## Linear Algebra Exercise Pack (Core + Python)

# %% [markdown]
# Designed for your Maths–DS–ML Sprint (15 days, 5h/day) David, this pack is meant to be used daily — each block is self‑contained and builds toward DS/ML fluency.

# %% [markdown]
# ### 📘 Block 6 — Linear Transformations

# %% [markdown]
# #### Visuals
#
# 21. (https://ts1.mm.bing.net/th?id=OIP.BQhb7uSrNRUFhTnTV0IWiAHaFj&pid=15.1&o=7&rm=3)
# 22. (https://ts3.mm.bing.net/th?id=OIP.OolQ-oWLh9g3bEEXEkEpOQHaEK&pid=15.1&o=7&rm=3)
# 23. (https://ts2.mm.bing.net/th?id=OIP.HDWO0TcMLSMBeCyi6KyZDgHaEK&pid=15.1&o=7&rm=3)
# 24. (https://ts2.mm.bing.net/th?id=OIP.vhDGkjwUPLaR2u8IC_olDwHaFv&pid=15.1&o=7&rm=3)

# %% [markdown]
# #### Definitions

# %% [markdown]
# #### Exercises
#
# Kernel and image
#
# Matrix representation
#
# Rank-nullity

# %% [markdown]
# #### Python tasks

# %%
import numpy as np

A = np.array([[1,2],[3,6]])
u = np.array([1,1])

print("A @ u =", A @ u)
print("Rank:", np.linalg.matrix_rank(A))
# Out:
# A @ u = [3 9]
# Rank: 1
